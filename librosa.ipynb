# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
from scipy.io import wavfile as wav

# %%
fn = 'LL-Q150_(fra)-Marxav-Breizh.wav'
librosa_audio, librosa_sample_rate = librosa.load(fn)
scipy_sample_rate, scipy_audio = wav.read(fn)

print("Original sample rate: {}".format(scipy_sample_rate))
print("Librosa sample rate: {}".format(librosa_sample_rate))
# Out:
# Original sample rate: 48000
# Librosa sample rate: 22050

# %%
y, sr = librosa.load('LL-Q150_(fra)-Marxav-Breizh.wav')
librosa.display.waveplot(y, sr= sr)

# %%
#!wget https://upload.wikimedia.org/wikipedia/commons/3/3c/LL-Q12107_%28bre%29-Marxav-Breizh.wav

# %%
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc = 40)

# %%
mfccs.shape
# Out:
# (40, 79)

# %%
plt.figure(figsize=(8,8))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
#plt.savefig('MFCCs.png')
#experiment.log_image('MFCCs.png')

# %%
file = 'LL-Q12107_(bre)-Marxav-Breizh.wav'
file = "LL-Q150_(fra)-Lepticed7-anticonstitutionnellement.wav"
y, sr = librosa.load(file)

librosa.display.waveplot(y, sr= sr)

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/0/06/LL-Q150_%28fra%29-Lepticed7-anticonstitutionnellement.wav
# Out:
# ...
# --2020-03-20 22:17:06--  https://upload.wikimedia.org/wikipedia/commons/0/06/LL-Q150_%28fra%29-Lepticed7-anticonstitutionnellement.wav
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 174892 (171K) [audio/x-wav]
# Saving to: ‘LL-Q150_(fra)-Lepticed7-anticonstitutionnellement.wav’
#
# LL-Q150_(fra)-Lepti 100%[===================>] 170.79K   902KB/s    in 0.2s
#
# 2020-03-20 22:17:07 (902 KB/s) - ‘LL-Q150_(fra)-Lepticed7-anticonstitutionnellement.wav’ saved [174892/174892]
